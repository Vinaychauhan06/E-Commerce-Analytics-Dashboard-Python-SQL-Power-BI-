# %%
import pandas as pd

# %%
cd = pd.read_csv("olist_customers_dataset.csv") 
gd=pd.read_csv("olist_geolocation_dataset.csv")
ot=pd.read_csv("olist_order_items_dataset.csv")
od=pd.read_csv("olist_orders_dataset.csv")
pyd=pd.read_csv("olist_order_payments_dataset.csv")
ord=pd.read_csv("olist_order_reviews_dataset.csv")
odd=pd.read_csv("olist_orders_dataset.csv")
prd=pd.read_csv("olist_products_dataset.csv")
osd=pd.read_csv("olist_sellers_dataset.csv")
pcn=pd.read_csv("product_category_name_translation.csv")

# %%
cd_clean=cd.copy()
gd_clean=gd.copy()
ot_clean=ot.copy()
od_clean=od.copy()
pyd_clean=pyd.copy()
ord_clean=ord.copy()
odd_clean=odd.copy()
prd_clean=prd.copy()
osd_clean=osd.copy()
pcn_clean=pcn.copy()

# %% [markdown]
# ### data cleaning

# %%
cd_clean.shape
gd_clean.shape
od_clean.shape
pyd_clean.shape
ord_clean.shape
prd_clean.shape
# Out:
# (32951, 9)

# %%
cd_clean.dtypes
gd_clean.dtypes
od_clean.dtypes
pyd_clean.dtypes
ord_clean.dtypes
prd_clean.dtypes
# Out:
# product_id                     object
# product_category_name          object
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object

# %% [markdown]
# ## Check Missing Values

# %% [markdown]
# ### Customer dataset

# %%
#total mising values in each column
cd_clean.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
#total missing values in the entire dataset
print(cd_clean.isnull().sum().sum())
# Out:
# 0

# %%
#percentage of missing values in each column
print((cd.isnull().sum()/len(cd)) * 100)
# Out:
# customer_id                 0.0
# customer_unique_id          0.0
# customer_zip_code_prefix    0.0
# customer_city               0.0
# customer_state              0.0
# dtype: float64

# %% [markdown]
# ### Geolocation dataset

# %%
gd_clean.isnull().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
print(gd_clean.isnull().sum().sum())
# Out:
# 0

# %%
print(gd_clean.duplicated().sum())
# Out:
# 261831

# %%
gd_clean[gd_clean.duplicated()]
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 15                              1046       -23.546081       -46.644820
# 44                              1046       -23.546081       -46.644820
# 65                              1046       -23.546081       -46.644820
# 66                              1009       -23.546935       -46.636588
# 67                              1046       -23.546081       -46.644820
# ...                              ...              ...              ...
# 1000153                        99970       -28.343273       -51.873734
# 1000154                        99950       -28.070493       -52.011342
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 15             sao paulo                SP
# ...

# %%
gd_clean.drop_duplicates(inplace=True)

# %% [markdown]
# ### order_items

# %%
od_clean.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
print(od_clean.isnull().sum().sum())
# Out:
# 4908

# %%
print(od_clean.isnull().sum()/len(od_clean) * 100)
# Out:
# order_id                         0.000000
# customer_id                      0.000000
# order_status                     0.000000
# order_purchase_timestamp         0.000000
# order_approved_at                0.160899
# order_delivered_carrier_date     1.793023
# order_delivered_customer_date    2.981668
# order_estimated_delivery_date    0.000000
# dtype: float64

# %%
od_clean[od_clean.isnull()]
# Out:
#       order_id customer_id order_status order_purchase_timestamp  \
# 0          NaN         NaN          NaN                      NaN
# 1          NaN         NaN          NaN                      NaN
# 2          NaN         NaN          NaN                      NaN
# 3          NaN         NaN          NaN                      NaN
# 4          NaN         NaN          NaN                      NaN
# ...        ...         ...          ...                      ...
# 99436      NaN         NaN          NaN                      NaN
# 99437      NaN         NaN          NaN                      NaN
# 99438      NaN         NaN          NaN                      NaN
# 99439      NaN         NaN          NaN                      NaN
# 99440      NaN         NaN          NaN                      NaN
#
#       order_approved_at order_delivered_carrier_date  \
# 0                   NaN                          NaN
# 1                   NaN                          NaN
# ...

# %%
od_clean.dropna(inplace=True)

# %%
print(od_clean.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### Order payments

# %%
pyd_clean.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
print(pyd_clean.isnull().sum().sum())
# Out:
# 0

# %%
print(pyd_clean.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### order reviews dataset

# %%
ord_clean.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
ord_clean.isnull().sum()/len(ord_clean) * 100
# Out:
# review_id                   0.000000
# order_id                    0.000000
# review_score                0.000000
# review_comment_title       88.341530
# review_comment_message     58.702532
# review_creation_date        0.000000
# review_answer_timestamp     0.000000
# dtype: float64

# %%
ord_clean.shape
# Out:
# (99224, 7)

# %%
ord_clean.dropna(inplace=True)

# %%
print(ord_clean.duplicated().sum())
# Out:
# 0

# %%
ord_clean.shape
# Out:
# (9839, 7)

# %% [markdown]
# ### order dataset

# %%
odd_clean.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
print(odd_clean.isnull().sum().sum())
# Out:
# 4908

# %%
odd_clean[odd_clean.isnull()]
# Out:
#       order_id customer_id order_status order_purchase_timestamp  \
# 0          NaN         NaN          NaN                      NaN
# 1          NaN         NaN          NaN                      NaN
# 2          NaN         NaN          NaN                      NaN
# 3          NaN         NaN          NaN                      NaN
# 4          NaN         NaN          NaN                      NaN
# ...        ...         ...          ...                      ...
# 99436      NaN         NaN          NaN                      NaN
# 99437      NaN         NaN          NaN                      NaN
# 99438      NaN         NaN          NaN                      NaN
# 99439      NaN         NaN          NaN                      NaN
# 99440      NaN         NaN          NaN                      NaN
#
#       order_approved_at order_delivered_carrier_date  \
# 0                   NaN                          NaN
# 1                   NaN                          NaN
# ...

# %%
odd_clean.dropna(inplace=True)

# %%
print(odd_clean.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### product dataset

# %%
prd_clean.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
prd_clean.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
prd_clean[prd_clean.isnull()]
# Out:
#       product_id product_category_name  product_name_lenght  \
# 0            NaN                   NaN                  NaN
# 1            NaN                   NaN                  NaN
# 2            NaN                   NaN                  NaN
# 3            NaN                   NaN                  NaN
# 4            NaN                   NaN                  NaN
# ...          ...                   ...                  ...
# 32946        NaN                   NaN                  NaN
# 32947        NaN                   NaN                  NaN
# 32948        NaN                   NaN                  NaN
# 32949        NaN                   NaN                  NaN
# 32950        NaN                   NaN                  NaN
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 0                             NaN                 NaN               NaN
# 1                             NaN                 NaN               NaN
# ...

# %%
prd_clean.dropna(inplace=True)

# %%
prd_clean.duplicated().sum()
# Out:
# np.int64(0)

# %%
prd_clean
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %% [markdown]
# ### seller dataset

# %%
osd_clean
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
osd_clean.isnull().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
osd_clean.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### product category name transaltion

# %%
pcn_clean.isnull().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
pcn_clean.duplicated().sum()
# Out:
# np.int64(0)

# %%
pcn_clean
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %%
cd_clean=cd
gd_clean=gd
ot_clean=ot
od_clean=od
pyd_clean=pyd
ord_clean=ord
odd_clean=odd
prd_clean=prd
osd_clean=osd
pcn_clean=pcn

# %%
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
