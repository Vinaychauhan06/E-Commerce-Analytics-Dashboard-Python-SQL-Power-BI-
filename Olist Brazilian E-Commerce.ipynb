# %%
import pandas as pd

# %%
df = pd.read_csv("olist_customers_dataset.csv")

# %%
path = df_path  # current file path
if path.lower().endswith(('.xls', '.xlsx', '.xlsm', '.xlsb', '.odf', '.ods', '.odt')):
    xls = pd.ExcelFile(path)
    print(xls.sheet_names)
else:
    print(f"{path!r} is a CSV file; CSV files do not have sheet names.")
